# %%
#Creating a list of random numbers and printing all the even numbers in the list
numbers = [12, 45, 7, 28, 91, 34, 16, 53, 20, 81]
for x in numbers:
    if x % 2 == 0:
        print(x)
# Out:
# 12
# 28
# 34
# 16
# 20

# %%
#Creating a string and printing it in the reverse order
string = "bootcamp"
reverse_string = string[::-1]
print(reverse_string)
# Out:
# pmactoob
